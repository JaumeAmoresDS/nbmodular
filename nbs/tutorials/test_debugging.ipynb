# %%
#|default_exp tests.tutorials.test_debugging

# %%
#|export
#@@function first_data --test --data
def first_data():
    a = 1

# %%
#|export
#@@function second_data --test --data
def second_data():
    b = 2

# %%
#|export
#@@function first_test --test
def first_test():
    a = first_data()
    b = second_data()
    assert a+b == 3
